# %%
import pandas as pd

store_mapping = pd.read_csv("store_mapping.csv")
store_mapping["marketplace_toko"] = (
    store_mapping["nama_marketplace"] + store_mapping["nama_toko"]
)
store_mapping_dict = pd.Series(
    store_mapping["nama_toko"].values, index=store_mapping["marketplace_toko"]
)

# %%
store_mapping
# Out:
#    nama_marketplace                     nama_toko  \
# 0            Lazada                       enzhico
# 1            Lazada                 enzhico store
# 2            Lazada                       erassgo
# 3            Lazada              erassgo store id
# 4            Lazada                        kudaku
# 5            Lazada                  zhi yang yao
# 6            Lazada   zhi yang yao store makassar
# 7            Shopee                       enzhico
# 8            Shopee                 enzhicoÂ shop
# 9            Shopee                 enzhico store
# 10           Shopee                    erassgo.co
# 11           Shopee  juwara herbal official store
# 12           Shopee                        kudaku
# 13           Shopee                     kudaku id
# 14           Shopee              kudaku indonesia
# 15           Shopee         kudaku official store
# 16           Shopee                  kudaku store
# 17           Shopee                  zhi yang yao
# ...
